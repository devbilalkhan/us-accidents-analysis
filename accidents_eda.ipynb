# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import numpy as np

# %%
df = pd.read_csv("data/US_Accidents_March23.csv", nrows=1000)

# %%
df_loc = df.loc[(~df.Start_Lat.isna()) & (~df.Start_Lng.isna())]

# %%
def create_map(df_loc, latitude, longitude, zoom):
    location_data = np.array(df_loc[["Start_Lat", "Start_Lng"]])
    marker_cluster = MarkerCluster(locations = location_data)
    world_coords = [latitude, longitude]
    world_map = folium.Map(location = world_coords, zoom_start=zoom)
    marker_cluster.add_to(world_map)
    return world_map

# %%
map = create_map(df_loc, 39.50, -98.35, 4)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2651f3754d42e3049db1c6413ae39753 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2651f3754d42e3049db1c6413ae39753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2651f3754d42e3049db1c6413ae39753 = L.map(
#                 &quot;map_2651f3754d42e3049db1c6413ae39753&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaf2d4051d6dd71f46226a82202a63b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaf2d4051d6dd71f46226a82202a63b9.addTo(map_2651f3754d42e3049db1c6413ae39753);
#
#
#             var marker_cluster_6cbd47830024c4c77f447f13cac8c920 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_cb64acb5c7480640652bf8f09104ad37 = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_2a125f94caa3026e249cc0e0d5d0b429 = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_40e5db8fcf508ebeac9196df98715894 = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_4005a5dc26dd4c660576a27a23a30a3f = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_b42d0dc4e8dc1b07e8b7f321545137a4 = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_47d61a7ba86136a90ff24f961403e9bc = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_9116e033140f53f4467d240e2d89a0e6 = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_41ccc58ec32029395bcba51816aae265 = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_2561e5aaf0cea0c96a4e1925461c6e79 = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_d06611d77035819cb2cec105dc2e0d0e = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_56834ce0d75077d65370870659507bc2 = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_22237bd35cd2b2fe90d43b9d81e970be = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_359de63235cdcc488710e0add2af7c79 = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_d35b257cf99b77840ea4a31fa14ac5e8 = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_1249b5e0b8ca2f0d54575cf2cedf6f8d = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_08b3c1d13b3162ac00455cb0c464abe8 = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_6cbd47830024c4c77f447f13cac8c920);
#
#
#             var marker_98c275c01a30e8e5d06c7bc35db66ac7 = L.marker(
#                 [39.748329, -84.224007],
#                 {}
#             ).addT

# %%
map = create_map(df_loc, 40.712776, -74.005974, 10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ae5f9647c33a7d80296caaf76a8e6b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ae5f9647c33a7d80296caaf76a8e6b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ae5f9647c33a7d80296caaf76a8e6b4 = L.map(
#                 &quot;map_1ae5f9647c33a7d80296caaf76a8e6b4&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60b47a2d1e430d4bd2abd5e195fbf118 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_60b47a2d1e430d4bd2abd5e195fbf118.addTo(map_1ae5f9647c33a7d80296caaf76a8e6b4);
#
#
#             var marker_cluster_590aa44852ebfbed23d872ed57850ddf = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_09ad5bb47ef8df0105a82c0921222650 = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_2521ba82b27536ff82c055b3dd542829 = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_afa0f46c039fa0cec65bce384f9631ed = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_8943069ab75e16025a1baef78355f3e1 = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_86d34aeab3a06e3602f4b9ab5e99b80a = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_c1bbd55969273fae1c3faa6c25ce4d06 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_f38eef5a7f6918782b25e3011dc41c20 = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_daee61ab5234c3dc686c33fe9bf0521d = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_45002d5c57dda4b032cca3a52d29c6f0 = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_790714e439d8e058c1299e0b3f865f86 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_2d863512d333f41b14e280c75d76cce4 = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_c7eb0a221279f697acb725f9af1a041a = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_be5a1feb0c8c319666b6a20e064b92f2 = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_b71315599e8a4fd463ef226af037e3ff = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_b943707579ce6215a65b87357ad962f3 = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_7fe3c2e44b8649ae0c34ef1a689a238d = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_590aa44852ebfbed23d872ed57850ddf);
#
#
#             var marker_8f3eb96127d9abc59a9be3da0545bea0 = L.marker(
#                 [39.748329, -84.224007],
#                 {}

# %%
map = create_map(df_loc, 37.774929, -122.419416, 10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ec7a5922bfaa2fdb123d30a2af168b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ec7a5922bfaa2fdb123d30a2af168b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ec7a5922bfaa2fdb123d30a2af168b9 = L.map(
#                 &quot;map_3ec7a5922bfaa2fdb123d30a2af168b9&quot;,
#                 {
#                     center: [37.774929, -122.419416],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0c3cb8fef11a571be0607ba980e15e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0c3cb8fef11a571be0607ba980e15e9.addTo(map_3ec7a5922bfaa2fdb123d30a2af168b9);
#
#
#             var marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_e7188e5a57d0b2611632ef86c1d72d6c = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_f18fd5218ef05c0a3e51165a99e58c6c = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_0913b7bf32f23a1f501b9c991f60a3b5 = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_4197c25b984674648941f0c774f168dc = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_ce293a700bbb6ac940c45cff08d6376a = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_e19a69145c2bc49b6255ea1e5af0b2f6 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_ca4aa5589cc05e09b581fd564fa39b2a = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_ba30c0c3c8dac411f7d3c2a5216d9bd3 = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_3ecd0a8515fbee91f8ff2278e9e9f37e = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_637cb7b4ba09c6840c978eb7f8e35356 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_9127c889c086ecb87ad554d14689305e = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_f4ab35450c6f7d7cf8a8baa86766ee78 = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_71ea3c56fbff12022bff69839ecc3d03 = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_c84c73b6cd41810179a853d3eca296b4 = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_d5f481c03ae3fd947096d3b9596e27cb = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_823631fa0b9a65fa178194a771fec401 = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_c0247355e808e4c8a5fe5a8e043a64e2);
#
#
#             var marker_547a806701537c9a76c3e8611af642b0 = L.marker(
#                 [39.748329, -84.224007],
#                 {}

# %%
map_la = create_map(df_loc, 34.052235, -118.243683, 10)
map_la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53d4cc7b33dc9c641e1a72f34f4bb3b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53d4cc7b33dc9c641e1a72f34f4bb3b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53d4cc7b33dc9c641e1a72f34f4bb3b4 = L.map(
#                 &quot;map_53d4cc7b33dc9c641e1a72f34f4bb3b4&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_933549df80c66dd2ead7895b6b3e5145 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_933549df80c66dd2ead7895b6b3e5145.addTo(map_53d4cc7b33dc9c641e1a72f34f4bb3b4);
#
#
#             var marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_9da716a6a61d9255aca15fc3f1b7549d = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_c35dbb4b2dadc5b95ca657e58b67fd01 = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_3635325a8819af214450ad554aadcedc = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_9880f442429421d05b8409384c95b574 = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_1ed4f77aa3975ffc1d54c48d87b12fea = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_fd19d17e1c23492f982e490899bcecba = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_acbc8bb9730ddca5e52d4d641998d380 = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_a1463103ca308591f0bef1c27d44a869 = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_7069ffbc069a6906257d4285fcf80dec = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_20c42c251ece0312b6bf1825958c9c4e = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_497522fa321711b39d28668fc0e6414c = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_e357557648833dedf2f2a49ab6cc6b22 = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_ee70295e7e541d7e1f87a0246a341955 = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_fac6ef47042a21cb3694ba422013dd2f = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_9a638dcf773338a790beb0424cfb1adb = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_b04bb12e559e15cb617f84528c418a32 = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_8e8af5ddb2876c92c79ea9acd26bcefb);
#
#
#             var marker_292995bd928ee12d4c2239b421432267 = L.marker(
#                 [39.748329, -84.224007],
#                 {}

# %%
map_chi = create_map(df_loc, 41.878113, -87.629799, 10)
map_chi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ab434e0042dc970202c66ab67df5c9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ab434e0042dc970202c66ab67df5c9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ab434e0042dc970202c66ab67df5c9d = L.map(
#                 &quot;map_8ab434e0042dc970202c66ab67df5c9d&quot;,
#                 {
#                     center: [41.878113, -87.629799],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad5258f8c5f7e12d859975dc6940de3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad5258f8c5f7e12d859975dc6940de3a.addTo(map_8ab434e0042dc970202c66ab67df5c9d);
#
#
#             var marker_cluster_e5fbeb4844913dc434d4483970a921d7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_6934d1e7f0dc1845b965ce58d1343b54 = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_e345ee7956a645a143d885b6b9f19dcc = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_90dff375f898c34eef8b403ebe0f530d = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_bb30ee93daa1b8aeba9d2a2e0e698da5 = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_054d12334bd3c401ea7dc813ad3c139d = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_217cc4c1f9321ace4668c9d5092e0dbe = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_e5b1814c2a088535b1894e2f81428d26 = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_9e8d0a06c13204c255de58b6ba602bf0 = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_f9267a6a56665d7f8b3735e265400048 = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_082ac21b8fdfa68c2387bb917672471d = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_86c50cbe1388f2af28672d8f0a41b1bb = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_e64b28c4440d237ed2941eb049ee8694 = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_51ea2bfed068a7984cd392e9072a3f1d = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_bb4064bb27b5396530b8b548f94f907c = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_c4394904810cb85d56edbdb0f7fd13d6 = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_fe66e420bd5734e6e7e6b6b76e3aecef = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_e5fbeb4844913dc434d4483970a921d7);
#
#
#             var marker_631729045480ecfc7c3e29c1e9e33cb1 = L.marker(
#                 [39.748329, -84.224007],
#                 {}

# %%
map_dal = create_map(df_loc, 32.776665, -96.796989, 10)
map_dal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ecff9a77c62c527838f82b77462cb9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ecff9a77c62c527838f82b77462cb9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ecff9a77c62c527838f82b77462cb9b = L.map(
#                 &quot;map_2ecff9a77c62c527838f82b77462cb9b&quot;,
#                 {
#                     center: [32.776665, -96.796989],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6bfcd0a9c3c883b886a350c4f15f148 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d6bfcd0a9c3c883b886a350c4f15f148.addTo(map_2ecff9a77c62c527838f82b77462cb9b);
#
#
#             var marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_340ed009767474ad1800027dff1f6a1a = L.marker(
#                 [39.865147, -84.058723],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_9ae8fd136610b300b5c0797ae1dacf17 = L.marker(
#                 [39.92805900000001, -82.831184],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_d9468f441cc72c0db62273eec4e142f6 = L.marker(
#                 [39.063148, -84.032608],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_0066c7f94fb942aa332d50c5458f3acd = L.marker(
#                 [39.747753, -84.20558199999998],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_c16e06dbaf949ca8080c02d2ff76c1c9 = L.marker(
#                 [39.627781, -84.188354],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_a23bb8dc1f4750e94c765bbcb9f83a99 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_03ded137e03fdf015454236156094217 = L.marker(
#                 [39.758274, -84.23050699999997],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_0e033a11709996447fbf7876b4a43824 = L.marker(
#                 [39.770382, -84.194901],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_facdf89cc7930825754434cd793f80d3 = L.marker(
#                 [39.778061, -84.172005],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_8d5137bdd8e8c31fa5b31743bdd000d4 = L.marker(
#                 [40.10059, -82.92519399999998],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_82278865efb1727b7b18c657cf3c977f = L.marker(
#                 [39.952812, -83.119293],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_ad7c4808590237c7392a497f80e9d681 = L.marker(
#                 [39.932709, -82.83091],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_983274487c3b53371fa0e6ed98cf4321 = L.marker(
#                 [39.737633, -84.14993299999998],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_b763363e12095b107d1fddd69ac83223 = L.marker(
#                 [39.79076, -84.241547],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_343b2089db93951182bafee1fceb348e = L.marker(
#                 [39.972038, -82.913521],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_492a11278058cf995ea3fbf02e0b50ae = L.marker(
#                 [39.745888, -84.17041],
#                 {}
#             ).addTo(marker_cluster_1d9f4e063dc4ef4b952141e9f39aae9e);
#
#
#             var marker_b17eb23f457850bfe81bdba31bae79a3 = L.marker(
#                 [39.748329, -84.224007],
#                 {}
